# %%
df=spark.read.format('csv').option("header","true").option('inferSchema','true').load('/Volumes/workspace/databricks_poc/poc')
df.display()

# %%
from pyspark.sql.functions import concat,lit,col
df1=df.withColumn('Full_Name',concat(col('First Name'),lit(' '),col('Last Name')))
df1.display()
